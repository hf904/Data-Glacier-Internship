# %% [markdown]
# # Week 6: File ingestion and schema validation
# ## Name: Hassan Faheem

# %%
import time
import csv
import pandas as pd
import dask.dataframe as dd
# Out:
# C:\Users\User\anaconda3\lib\site-packages\dask\dataframe\utils.py:366: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# C:\Users\User\anaconda3\lib\site-packages\dask\dataframe\utils.py:366: FutureWarning: pandas.Float64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)
# C:\Users\User\anaconda3\lib\site-packages\dask\dataframe\utils.py:366: FutureWarning: pandas.UInt64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   _numeric_index_types = (pd.Int64Index, pd.Float64Index, pd.UInt64Index)

# %%
pip install pandas_schema
# Out:
# Requirement already satisfied: pandas_schema in c:\users\user\anaconda3\lib\site-packages (0.3.6)
# Requirement already satisfied: pandas>=0.19 in c:\users\user\anaconda3\lib\site-packages (from pandas_schema) (1.4.1)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from pandas_schema) (20.4)
# Requirement already satisfied: numpy in c:\users\user\anaconda3\lib\site-packages (from pandas_schema) (1.19.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.19->pandas_schema) (2.8.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas>=0.19->pandas_schema) (2020.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pandas_schema) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging->pandas_schema) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)

# %%
# %%time
with open('parkingFines.csv') as csv_file:
    csv_reader = csv.DictReader(csv_file, delimiter=',')
    line_count = 0
# Out:
# Wall time: 0 ns

# %%
csv_reader

# %%
# %%time
data =pd.read_csv("parkingFines.csv")
# Out:
# <timed exec>:1: DtypeWarning: Columns (18,38) have mixed types. Specify dtype option on import or set low_memory=False.
# Wall time: 1min 16s

# %%
# %%time
chunks = pd.read_csv("parkingFines.csv", chunksize=100000)
data1 = pd.concat(chunks)
# Out:
# <timed exec>:2: DtypeWarning: Columns (18,38) have mixed types. Specify dtype option on import or set low_memory=False.
# <timed exec>:2: DtypeWarning: Columns (18,38) have mixed types. Specify dtype option on import or set low_memory=False.
# <timed exec>:2: DtypeWarning: Columns (18,29,38,39) have mixed types. Specify dtype option on import or set low_memory=False.
# Wall time: 1min 38s

# %%
data.head()

df=data.sample(frac=0.01)

# %%
df
# Out:
#           Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 4822203       8546505720  BJFD970                 ON        PAS  05/06/2017
# 10507335      8558561680  42767JM                 NY        COM  06/27/2017
# 5501906       8157528884  90589MH                 NY        COM  09/27/2016
# 1201871       7499875180  HHH7737                 NY        PAS  01/24/2017
# 6680637       8558407897  EMF7733                 NY        PAS  05/25/2017
# ...                  ...      ...                ...        ...         ...
# 77501         8553901609  GJE3286                 NY        PAS  04/26/2017
# 10334431      8347532990  FAL1410                 NY        PAS  11/19/2016
# 8094579       8552615710   AP860R                 NJ        PAS  06/21/2017
# 10176241      7596093358  ERS4432                 NY        PAS  11/14/2016
# 5669861       4628870056  HLN1560                 NY        PAS  12/22/2016
#
#           Violation Code Vehicle Body Type Vehicle Make Issuing Agency  \
# 4822203               38              SUBN        DODGE              T
# 10507335              40              DELV        INTER              T
# 5501906               78               VAN         FORD              T
# 1201871               21              4DSD        HONDA              T
# 6680637               38              SUBN        TOYOT              T
# ...                  ...               ...          ...            ...
# 77501                 20              4DSD        HONDA              T
# 10334431              14              SUBN        LEXUS              T
# 8094579               19              DELV         FORD              T
# 10176241              14              SUBN        PORSC              T
# 5669861               36              4DSD        NISSA              V
#
#           Street Code1  ...  Vehicle Color  Unregistered Vehicle?  \
# 4822203              0  ...          BLACK                    NaN
# 10507335          8590  ...          BROWN                    NaN
# 5501906           8580  ...             WH                    NaN
# 1201871          57690  ...             BL                    NaN
# 6680637          15340  ...             GL                    NaN
# ...                ...  ...            ...                    ...
# 77501             7300  ...             WH                    NaN
# 10334431         22680  ...             GY                    NaN
# 8094579          64290  ...          YELLO                    NaN
# 10176241             0  ...          BLACK                    NaN
# 5669861              0  ...             WH                    NaN
#
#           Vehicle Year  Meter Number  Feet From Curb  Violation Post Code  \
# 4822203              0           NaN               0                   10
# 10507335          1997           NaN               0                 23-P
# 5501906           2016           NaN               0                 C 31
# 1201871           2013           NaN               0                   29
# 6680637           2005           NaN               0                   10
# ...                ...           ...             ...                  ...
# 77501             2015           NaN               0                    U
# 10334431          2002           NaN               0                 15 3
# 8094579              0           NaN               0                   31
# 10176241          2008           NaN               0                 01 8
# 5669861           2016           NaN               0                  NaN
#
#                    Violation Description No Standing or Stopping Violation  \
# 4822203   38-Failure to Display Muni Rec                               NaN
# 10507335                 40-Fire Hydrant                               NaN
# 5501906   78-Nighttime PKG on Res Street                               NaN
# 1201871     21-No Parking (street clean)                               NaN
# 6680637   38-Failure to Display Muni Rec                               NaN
# ...                                  ...                               ...
# 77501           20A-No Parking (Non-COM)                               NaN
# 10334431                  14-No Standing                               NaN
# 8094579           19-No Stand (bus stop)                               NaN
# 10176241                  14-No Standing                               NaN
# 5669861   PHTO SCHOOL ZN SPEED VIOLATION                               NaN
#
#          Hydrant Violation Double Parking Violation
# 4822203                NaN                      NaN
# 10507335               NaN                      NaN
# 5501906                NaN                      NaN
# 1201871                NaN                      NaN
# 6680637                NaN                      NaN
# ...                    ...                      ...
# 77501                  NaN                      NaN
# 10334431               NaN                      NaN
# 8094579                NaN                      NaN
# 10176241               NaN                      NaN
# 5669861                NaN                      NaN
#
# [108030 rows x 43 columns]

# %%
df.to_csv('test.csv', index=False)

# %%
# %%time
df1= dd.read_csv("parkingFines.csv")
# Out:
# Wall time: 77.9 ms

# %%
pip install ray
# Out:
# Requirement already satisfied: ray in c:\users\user\anaconda3\lib\site-packages (1.11.0)
# Requirement already satisfied: filelock in c:\users\user\anaconda3\lib\site-packages (from ray) (3.0.12)
# Requirement already satisfied: jsonschema in c:\users\user\anaconda3\lib\site-packages (from ray) (3.2.0)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in c:\users\user\anaconda3\lib\site-packages (from ray) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# Requirement already satisfied: protobuf>=3.15.3 in c:\users\user\anaconda3\lib\site-packages (from ray) (3.20.0)
# Requirement already satisfied: redis>=3.5.0 in c:\users\user\anaconda3\lib\site-packages (from ray) (4.2.2)
# Requirement already satisfied: numpy>=1.16 in c:\users\user\anaconda3\lib\site-packages (from ray) (1.19.1)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in c:\users\user\anaconda3\lib\site-packages (from ray) (1.43.0)
# Requirement already satisfied: pyyaml in c:\users\user\anaconda3\lib\site-packages (from ray) (6.0)
# Requirement already satisfied: click>=7.0 in c:\users\user\anaconda3\lib\site-packages (from ray) (7.1.2)
# Requirement already satisfied: attrs in c:\users\user\anaconda3\lib\site-packages (from ray) (19.3.0)
# Requirement already satisfied: six>=1.5.2 in c:\users\user\anaconda3\lib\site-packages (from grpcio<=1.43.0,>=1.28.1->ray) (1.15.0)
# Requirement already satisfied: async-timeout>=4.0.2 in c:\users\user\anaconda3\lib\site-packages (from redis>=3.5.0->ray) (4.0.2)
# Requirement already satisfied: packaging>=20.4 in c:\users\user\anaconda3\lib\site-packages (from redis>=3.5.0->ray) (20.4)
# Requirement already satisfied: deprecated>=1.2.3 in c:\users\user\anaconda3\lib\site-packages (from redis>=3.5.0->ray) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\user\anaconda3\lib\site-packages (from deprecated>=1.2.3->redis>=3.5.0->ray) (1.11.2)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging>=20.4->redis>=3.5.0->ray) (2.4.7)
# Requirement already satisfied: setuptools in c:\users\user\anaconda3\lib\site-packages (from jsonschema->ray) (49.2.0.post20200714)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\user\anaconda3\lib\site-packages (from jsonschema->ray) (0.16.0)

# %%
pip install modin
# Out:
# Requirement already satisfied: modin in c:\users\user\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: fsspec in c:\users\user\anaconda3\lib\site-packages (from modin) (0.7.4)
# Requirement already satisfied: numpy>=1.18.5 in c:\users\user\anaconda3\lib\site-packages (from modin) (1.19.1)
# Requirement already satisfied: pandas==1.4.1 in c:\users\user\anaconda3\lib\site-packages (from modin) (1.4.1)
# Requirement already satisfied: packaging in c:\users\user\anaconda3\lib\site-packages (from modin) (20.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas==1.4.1->modin) (2020.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\user\anaconda3\lib\site-packages (from pandas==1.4.1->modin) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas==1.4.1->modin) (1.15.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\user\anaconda3\lib\site-packages (from packaging->modin) (2.4.7)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\user\anaconda3\lib\site-packages)

# %%
import os
os.environ["MODIN_ENGINE"] = "ray"  # Modin will use Ray
import ray
ray.init()
import modin.pandas as ray_pd

# %%
#%time
#df11 = ray_pd.read_csv('parkingFines.csv')

# %%
data.head()
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      5092469481  GZH7067                 NY        PAS  07/10/2016
# 1      5092451658  GZH7067                 NY        PAS  07/08/2016
# 2      4006265037  FZX9232                 NY        PAS  08/23/2016
# 3      8478629828  66623ME                 NY        COM  06/14/2017
# 4      7868300310  37033JV                 NY        COM  11/21/2016
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0               7              SUBN        TOYOT              V             0
# 1               7              SUBN        TOYOT              V             0
# 2               5              SUBN         FORD              V             0
# 3              47              REFG        MITSU              T         10610
# 4              69              DELV        INTER              T         10510
#
#    ...  Vehicle Color  Unregistered Vehicle?  Vehicle Year  Meter Number  \
# 0  ...             GY                    NaN          2001           NaN
# 1  ...             GY                    NaN          2001           NaN
# 2  ...             BK                    NaN          2004           NaN
# 3  ...             WH                    NaN          2007           NaN
# 4  ...          WHITE                    NaN          2007           NaN
#
#    Feet From Curb  Violation Post Code          Violation Description  \
# 0               0                  NaN   FAILURE TO STOP AT RED LIGHT
# 1               0                  NaN   FAILURE TO STOP AT RED LIGHT
# 2               0                  NaN             BUS LANE VIOLATION
# 3               0                   04          47-Double PKG-Midtown
# 4               0                 31 6  69-Failure to Disp Muni Recpt
#
#   No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# 0                               NaN               NaN                      NaN
# 1                               NaN               NaN                      NaN
# 2                               NaN               NaN                      NaN
# 3                               NaN               NaN                      NaN
# 4                               NaN               NaN                      NaN
#
# [5 rows x 43 columns]

# %%
data.columns=data.columns.str.replace('[#,@,&]','')
data.head()
# Out:
# FutureWarning: The default value of regex will change from True to False in a future version.
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      5092469481  GZH7067                 NY        PAS  07/10/2016
# 1      5092451658  GZH7067                 NY        PAS  07/08/2016
# 2      4006265037  FZX9232                 NY        PAS  08/23/2016
# 3      8478629828  66623ME                 NY        COM  06/14/2017
# 4      7868300310  37033JV                 NY        COM  11/21/2016
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0               7              SUBN        TOYOT              V             0
# 1               7              SUBN        TOYOT              V             0
# 2               5              SUBN         FORD              V             0
# 3              47              REFG        MITSU              T         10610
# 4              69              DELV        INTER              T         10510
#
#    ...  Vehicle Color  Unregistered Vehicle?  Vehicle Year  Meter Number  \
# 0  ...             GY                    NaN          2001           NaN
# 1  ...             GY                    NaN          2001           NaN
# 2  ...             BK                    NaN          2004           NaN
# 3  ...             WH                    NaN          2007           NaN
# 4  ...          WHITE                    NaN          2007           NaN
#
#    Feet From Curb  Violation Post Code          Violation Description  \
# 0               0                  NaN   FAILURE TO STOP AT RED LIGHT
# 1               0                  NaN   FAILURE TO STOP AT RED LIGHT
# 2               0                  NaN             BUS LANE VIOLATION
# 3               0                   04          47-Double PKG-Midtown
# 4               0                 31 6  69-Failure to Disp Muni Recpt
#
#   No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# 0                               NaN               NaN                      NaN
# 1                               NaN               NaN                      NaN
# 2                               NaN               NaN                      NaN
# 3                               NaN               NaN                      NaN
# 4                               NaN               NaN                      NaN
#
# [5 rows x 43 columns]

# %%
data.columns=data.columns.str.replace(' ','_')
data.head()
# Out:
#    Summons_Number Plate_ID Registration_State Plate_Type  Issue_Date  \
# 0      5092469481  GZH7067                 NY        PAS  07/10/2016
# 1      5092451658  GZH7067                 NY        PAS  07/08/2016
# 2      4006265037  FZX9232                 NY        PAS  08/23/2016
# 3      8478629828  66623ME                 NY        COM  06/14/2017
# 4      7868300310  37033JV                 NY        COM  11/21/2016
#
#    Violation_Code Vehicle_Body_Type Vehicle_Make Issuing_Agency  Street_Code1  \
# 0               7              SUBN        TOYOT              V             0
# 1               7              SUBN        TOYOT              V             0
# 2               5              SUBN         FORD              V             0
# 3              47              REFG        MITSU              T         10610
# 4              69              DELV        INTER              T         10510
#
#    ...  Vehicle_Color  Unregistered_Vehicle?  Vehicle_Year  Meter_Number  \
# 0  ...             GY                    NaN          2001           NaN
# 1  ...             GY                    NaN          2001           NaN
# 2  ...             BK                    NaN          2004           NaN
# 3  ...             WH                    NaN          2007           NaN
# 4  ...          WHITE                    NaN          2007           NaN
#
#    Feet_From_Curb  Violation_Post_Code          Violation_Description  \
# 0               0                  NaN   FAILURE TO STOP AT RED LIGHT
# 1               0                  NaN   FAILURE TO STOP AT RED LIGHT
# 2               0                  NaN             BUS LANE VIOLATION
# 3               0                   04          47-Double PKG-Midtown
# 4               0                 31 6  69-Failure to Disp Muni Recpt
#
#   No_Standing_or_Stopping_Violation Hydrant_Violation Double_Parking_Violation
# 0                               NaN               NaN                      NaN
# 1                               NaN               NaN                      NaN
# 2                               NaN               NaN                      NaN
# 3                               NaN               NaN                      NaN
# 4                               NaN               NaN                      NaN
#
# [5 rows x 43 columns]

# %%
data.columns
# Out:
# Index(['Summons_Number', 'Plate_ID', 'Registration_State', 'Plate_Type',
#        'Issue_Date', 'Violation_Code', 'Vehicle_Body_Type', 'Vehicle_Make',
#        'Issuing_Agency', 'Street_Code1', 'Street_Code2', 'Street_Code3',
#        'Vehicle_Expiration_Date', 'Violation_Location', 'Violation_Precinct',
#        'Issuer_Precinct', 'Issuer_Code', 'Issuer_Command', 'Issuer_Squad',
#        'Violation_Time', 'Time_First_Observed', 'Violation_County',
#        'Violation_In_Front_Of_Or_Opposite', 'House_Number', 'Street_Name',
#        'Intersecting_Street', 'Date_First_Observed', 'Law_Section',
#        'Sub_Division', 'Violation_Legal_Code', 'Days_Parking_In_Effect____',
#        'From_Hours_In_Effect', 'To_Hours_In_Effect', 'Vehicle_Color',
#        'Unregistered_Vehicle?', 'Vehicle_Year', 'Meter_Number',
#        'Feet_From_Curb', 'Violation_Post_Code', 'Violation_Description',
#        'No_Standing_or_Stopping_Violation', 'Hydrant_Violation',
#        'Double_Parking_Violation'],
#       dtype='object')

# %%
# %%writefile testutil.py
import logging
import os
import subprocess
import yaml
import pandas as pd
import datetime 
import gc
import re

################
# File Reading #
################

def read_config_file(filepath):
    with open(filepath, 'r') as stream:
        try:
            return yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            logging.error(exc)

def replacer(string, char):
    pattern = char + '{2,}'
    string = re.sub(pattern, char, string) 
    return string


def col_header_val(df,table_config):
    '''
    replace whitespaces in the column
    and standardized column names
    '''
    df.columns = df.columns.str.lower()
    df.columns = df.columns.str.replace('[^\w]','_',regex=True)
    df.columns = list(map(lambda x: x.strip('_'), list(df.columns)))
    df.columns = list(map(lambda x: replacer(x,'_'), list(df.columns)))
    expected_col = list(map(lambda x: x.lower(),  table_config['columns']))
    expected_col.sort()
    df.columns =list(map(lambda x: x.lower(), list(df.columns)))
    df = df.reindex(sorted(df.columns), axis=1)
    if len(df.columns) == len(expected_col) and list(expected_col)  == list(df.columns):
        print("column name and column length validation passed")
        return 1
    else:
        print("column name and column length validation failed")
        mismatched_columns_file = list(set(df.columns).difference(expected_col))
        print("Following File columns are not in the YAML file",mismatched_columns_file)
        missing_YAML_file = list(set(expected_col).difference(df.columns))
        print("Following YAML columns are not in the file uploaded",missing_YAML_file)
        logging.info(f'df columns: {df.columns}')
        logging.info(f'expected columns: {expected_col}')
        return 0
# Out:
# Overwriting testutil.py

# %%
# %%writefile file.yaml
# file_type: csv
# dataset_name: testfile
# file_name: test
# table_name: edsurv
# inbound_delimiter: ","
# outbound_delimiter: "|"
# skip_leading_rows: 1
# columns:
#     -Summons_Number
#     -Plate_ID
#     -Registration_State
#     -Plate_Type
#     -Issue_Date
#     -Violation_Code
#     -Vehicle_Body_Type
#     -Vehicle_Make
#     -Issuing_Agency
#     -Street_Code1
#     -Street_Code2
#     -Street_Code3
#     -Vehicle_Expiration_Date
#     -Violation_Location
#     -Violation_Precinct
#     -Issuer_Precinct
#     -Issuer_Code
#     -Issuer_Command
#     -Issuer_Squad
#     -Violation_Time
#     -Time_First_Observed
#     -Violation_County
#     -Violation_In_Front_Of_Or_Opposite
#     -House_Number
#     -Street_Name
#     -Intersecting_Street
#     -Date_First_Observed
#     -Law_Section
#     -Sub_Division
#     -Violation_Legal_Code
#      -Days_Parking_In_Effect____
#     -From_Hours_In_Effect
#     -To_Hours_In_Effect
#     -Vehicle_Color
#     -Unregistered_Vehicle?
#     -Vehicle_Year
#     -Meter_Number
#     -Feet_From_Curb
#     -Violation_Post_Code
#     -Violation_Description
#     -No_Standing_or_Stopping_Violation
#     -Hydrant_Violation
#     -Double_Parking_Violation
#     -Latitude
#     -Longitude
#     -Community_Board
#     -Community_Council_
#     -Census_Tract
#     -BIN
#     -BBL
#     -NTA
# Out:
# Overwriting file.yaml

# %%
import testutil as util
config_data = util.read_config_file("file.yaml")

# %%
config_data['outbound_delimiter']
# Out:
# '|'

# %%
config_data
# Out:
# {'file_type': 'csv',
#  'dataset_name': 'testfile',
#  'file_name': 'test',
#  'table_name': 'edsurv',
#  'inbound_delimiter': ',',
#  'outbound_delimiter': '|',
#  'skip_leading_rows': 1,
#  'columns': '-Summons_Number -Plate_ID -Registration_State -Plate_Type -Issue_Date -Violation_Code -Vehicle_Body_Type -Vehicle_Make -Issuing_Agency -Street_Code1 -Street_Code2 -Street_Code3 -Vehicle_Expiration_Date -Violation_Location -Violation_Precinct -Issuer_Precinct -Issuer_Code -Issuer_Command -Issuer_Squad -Violation_Time -Time_First_Observed -Violation_County -Violation_In_Front_Of_Or_Opposite -House_Number -Street_Name -Intersecting_Street -Date_First_Observed -Law_Section -Sub_Division -Violation_Legal_Code -Days_Parking_In_Effect____ -From_Hours_In_Effect -To_Hours_In_Effect -Vehicle_Color -Unregistered_Vehicle? -Vehicle_Year -Meter_Number -Feet_From_Curb -Violation_Post_Code -Violation_Description -No_Standing_or_Stopping_Violation -Hydrant_Violation -Double_Parking_Violation -Latitude -Longitude -Community_Board -Community_Council_ -Census_Tract -BIN -BBL -NTA'}

# %%
import pandas as pd
df_sample = pd.read_csv("test.csv",delimiter=',')
df_sample.head()
# Out:
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      8546505720  BJFD970                 ON        PAS  05/06/2017
# 1      8558561680  42767JM                 NY        COM  06/27/2017
# 2      8157528884  90589MH                 NY        COM  09/27/2016
# 3      7499875180  HHH7737                 NY        PAS  01/24/2017
# 4      8558407897  EMF7733                 NY        PAS  05/25/2017
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              38              SUBN        DODGE              T             0
# 1              40              DELV        INTER              T          8590
# 2              78               VAN         FORD              T          8580
# 3              21              4DSD        HONDA              T         57690
# 4              38              SUBN        TOYOT              T         15340
#
#    ...  Vehicle Color  Unregistered Vehicle?  Vehicle Year  Meter Number  \
# 0  ...          BLACK                    NaN             0           NaN
# 1  ...          BROWN                    NaN          1997           NaN
# 2  ...             WH                    NaN          2016           NaN
# 3  ...             BL                    NaN          2013           NaN
# 4  ...             GL                    NaN          2005           NaN
#
#    Feet From Curb  Violation Post Code           Violation Description  \
# 0               0                   10  38-Failure to Display Muni Rec
# 1               0                 23-P                 40-Fire Hydrant
# 2               0                 C 31  78-Nighttime PKG on Res Street
# 3               0                   29    21-No Parking (street clean)
# 4               0                   10  38-Failure to Display Muni Rec
#
#   No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# 0                               NaN               NaN                      NaN
# 1                               NaN               NaN                      NaN
# 2                               NaN               NaN                      NaN
# 3                               NaN               NaN                      NaN
# 4                               NaN               NaN                      NaN
#
# [5 rows x 43 columns]

# %%
file_type = config_data['file_type']
source_file = "./" + config_data['file_name'] + f'.{file_type}'
#print("",source_file)
df = pd.read_csv(source_file,config_data['inbound_delimiter'])
df.head()
# Out:
# FutureWarning: In a future version of pandas all arguments of read_csv except for the argument 'filepath_or_buffer' will be keyword-only.
#    Summons Number Plate ID Registration State Plate Type  Issue Date  \
# 0      8546505720  BJFD970                 ON        PAS  05/06/2017
# 1      8558561680  42767JM                 NY        COM  06/27/2017
# 2      8157528884  90589MH                 NY        COM  09/27/2016
# 3      7499875180  HHH7737                 NY        PAS  01/24/2017
# 4      8558407897  EMF7733                 NY        PAS  05/25/2017
#
#    Violation Code Vehicle Body Type Vehicle Make Issuing Agency  Street Code1  \
# 0              38              SUBN        DODGE              T             0
# 1              40              DELV        INTER              T          8590
# 2              78               VAN         FORD              T          8580
# 3              21              4DSD        HONDA              T         57690
# 4              38              SUBN        TOYOT              T         15340
#
#    ...  Vehicle Color  Unregistered Vehicle?  Vehicle Year  Meter Number  \
# 0  ...          BLACK                    NaN             0           NaN
# 1  ...          BROWN                    NaN          1997           NaN
# 2  ...             WH                    NaN          2016           NaN
# 3  ...             BL                    NaN          2013           NaN
# 4  ...             GL                    NaN          2005           NaN
#
#    Feet From Curb  Violation Post Code           Violation Description  \
# 0               0                   10  38-Failure to Display Muni Rec
# 1               0                 23-P                 40-Fire Hydrant
# 2               0                 C 31  78-Nighttime PKG on Res Street
# 3               0                   29    21-No Parking (street clean)
# 4               0                   10  38-Failure to Display Muni Rec
#
#   No Standing or Stopping Violation Hydrant Violation Double Parking Violation
# 0                               NaN               NaN                      NaN
# 1                               NaN               NaN                      NaN
# 2                               NaN               NaN                      NaN
# 3                               NaN               NaN                      NaN
# 4                               NaN               NaN                      NaN
#
# [5 rows x 43 columns]

# %%
print("columns of files are:" ,df.columns)
print("columns of YAML are:" ,config_data['columns'])
# Out:
# columns of files are: Index(['Summons Number', 'Plate ID', 'Registration State', 'Plate Type',
#        'Issue Date', 'Violation Code', 'Vehicle Body Type', 'Vehicle Make',
#        'Issuing Agency', 'Street Code1', 'Street Code2', 'Street Code3',
#        'Vehicle Expiration Date', 'Violation Location', 'Violation Precinct',
#        'Issuer Precinct', 'Issuer Code', 'Issuer Command', 'Issuer Squad',
#        'Violation Time', 'Time First Observed', 'Violation County',
#        'Violation In Front Of Or Opposite', 'House Number', 'Street Name',
#        'Intersecting Street', 'Date First Observed', 'Law Section',
#        'Sub Division', 'Violation Legal Code', 'Days Parking In Effect    ',
#        'From Hours In Effect', 'To Hours In Effect', 'Vehicle Color',
#        'Unregistered Vehicle?', 'Vehicle Year', 'Meter Number',
#        'Feet From Curb', 'Violation Post Code', 'Violation Description',
#        'No Standing or Stopping Violation', 'Hydrant Violation',
#        'Double Parking Violation'],
#       dtype='object')
# columns of YAML are: -Summons_Number -Plate_ID -Registration_State -Plate_Type -Issue_Date -Violation_Code -Vehicle_Body_Type -Vehicle_Make -Issuing_Agency -Street_Code1 -Street_Code2 -Street_Code3 -Vehicle_Expiration_Date -Violation_Location -Violation_Precinct -Issuer_Precinct -Issuer_Code -Issuer_Command -Issuer_Squad -Violation_Time -Time_First_Observed -Violation_County -Violation_In_Front_Of_Or_Opposite -House_Number -Street_Name -Intersecting_Street -Date_First_Observed -Law_Section -Sub_Division -Violation_Legal_Code -Days_Parking_In_Effect____ -From_Hours_In_Effect -To_Hours_In_Effect -Vehicle_Color -Unregistered_Vehicle? -Vehicle_Year -Meter_Number -Feet_From_Curb -Violation_Post_Code -Violation_Description -No_Standing_or_Stopping_Violation -Hydrant_Violation -Double_Parking_Violation -Latitude -Longitude -Community_Board -Community_Council_ -Census_Tract -BIN -BBL -NTA

# %%
util.col_header_val(df,config_data)
# Out:
# column name and column length validation failed
# Following File columns are not in the YAML file ['plate_type', 'vehicle_body_type', 'vehicle_year', 'days_parking_in_effect', 'feet_from_curb', 'street_code2', 'issuer_precinct', 'meter_number', 'violation_in_front_of_or_opposite', 'to_hours_in_effect', 'registration_state', 'street_code3', 'vehicle_color', 'plate_id', 'vehicle_make', 'double_parking_violation', 'street_name', 'violation_legal_code', 'hydrant_violation', 'issuer_command', 'issuer_code', 'summons_number', 'date_first_observed', 'violation_description', 'unregistered_vehicle', 'intersecting_street', 'issuer_squad', 'violation_time', 'street_code1', 'vehicle_expiration_date', 'issuing_agency', 'from_hours_in_effect', 'violation_county', 'time_first_observed', 'violation_location', 'violation_post_code', 'law_section', 'violation_code', 'sub_division', 'no_standing_or_stopping_violation', 'house_number', 'issue_date', 'violation_precinct']
# Following YAML columns are not in the file uploaded ['2', '?', 'x', 't', 'h', 'q', 'f', 'k', ' ', 'p', 'e', 'u', 'v', 'g', 'y', '3', 'b', 's', 'o', '-', '_', '1', 'c', 'n', 'd', 'w', 'm', 'i', 'r', 'a', 'l']
# 0

# %%
df.to_csv('test.csv.gz', compression='gzip', sep='|')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108030 entries, 0 to 108029
# Data columns (total 43 columns):
#  #   Column                             Non-Null Count   Dtype
# ---  ------                             --------------   -----
#  0   summons_number                     108030 non-null  int64
#  1   plate_id                           108022 non-null  object
#  2   registration_state                 108030 non-null  object
#  3   plate_type                         108030 non-null  object
#  4   issue_date                         108030 non-null  object
#  5   violation_code                     108030 non-null  int64
#  6   vehicle_body_type                  107621 non-null  object
#  7   vehicle_make                       107287 non-null  object
#  8   issuing_agency                     108030 non-null  object
#  9   street_code1                       108030 non-null  int64
#  10  street_code2                       108030 non-null  int64
#  11  street_code3                       108030 non-null  int64
#  12  vehicle_expiration_date            108030 non-null  int64
#  13  violation_location                 87226 non-null   float64
#  14  violation_precinct                 108030 non-null  int64
#  15  issuer_precinct                    108030 non-null  int64
#  16  issuer_code                        108030 non-null  int64
#  17  issuer_command                     87334 non-null   object
#  18  issuer_squad                       87321 non-null   object
#  19  violation_time                     108029 non-null  object
#  20  time_first_observed                8387 non-null    object
#  21  violation_county                   107655 non-null  object
#  22  violation_in_front_of_or_opposite  86317 non-null   object
#  23  house_number                       85088 non-null   object
#  24  street_name                        107976 non-null  object
#  25  intersecting_street                33772 non-null   object
#  26  date_first_observed                108030 non-null  int64
#  27  law_section                        108030 non-null  int64
#  28  sub_division                       108018 non-null  object
#  29  violation_legal_code               20697 non-null   object
#  30  days_parking_in_effect             80784 non-null   object
#  31  from_hours_in_effect               53674 non-null   object
#  32  to_hours_in_effect                 53674 non-null   object
#  33  vehicle_color                      106510 non-null  object
#  34  unregistered_vehicle               11269 non-null   float64
#  35  vehicle_year                       108030 non-null  int64
#  36  meter_number                       17825 non-null   object
#  37  feet_from_curb                     108030 non-null  int64
#  38  violation_post_code                76066 non-null   object
#  39  violation_description              96761 non-null   object
#  40  no_standing_or_stopping_violation  0 non-null       float64
#  41  hydrant_violation                  0 non-null       float64
#  42  double_parking_violation           0 non-null       float64
# dtypes: float64(5), int64(13), object(25)
# memory usage: 35.4+ MB
